# %% [markdown]
# # Python exercises from [the lab doc](https://learn.ucdpa.ie/pluginfile.php/133156/mod_resource/content/0/Unit_1_Lab_Introduction_To_CLI_and_Python.pdf)

# %%
# 1. Display three different messages.
"""
Welcome to Python
Welcome to Computer Science
Programming is fun
"""

# %%
# 2. Display the same message five times. 
#    Write a program that displays 'Welcome to Python' five times
"""
Welcome to Python
Welcome to Python
Welcome to Python
Welcome to Python
Welcome to Python
"""

# %%
# 3. Display a pattern.
#    We can just use a multiline string:

"""
FFFFFFF   U     U   NN     NN
FF        U     U   NNN    NN
FFFFFFF   U     U   NN N   NN
FF         U   U    NN  N  NN
FF          UUU     NN    NNN
"""

# %%
# 4. Print a table.
# We can just use a multiline string:
"""
a   a^2   a^3
1   1     1
2   4     8
3   9     27
4   16    64
"""

# %%
# 4. a) Print above table using the tab character \t 
#(Note: the output should have evenly spaced columns:
"""
a       a^2     a^3
1       1       1
2       4       8
3       9       27
4       16      64
"""

# %%
# 5. Compute the maths formula in the cell below:

# %% [markdown]
# #### Write a program that displays the result of:
#
# \begin{align}
#  result = \frac{9.5  X  4.5 - 2.5 X 3}{45.5 - 3.5}
# \end{align}

# %%
# Write code here 
# But see below walkthrough for help getting started...

# %% [markdown]
# #### Walkthrough: getting started with formula's...
# Below you can observe how to write code for the following forumla:
# \begin{align}
#  result = 6a^3 - \frac{8b^2 }{4c} + 11
# \end{align}

# %%
# Example values for a, b and c: leave them as is
a = 2
b = 3
c = 2

# %%
# converting the maths formula to code
result = 6 * a**3 - 2 * b**2 / c + 11

# %%
# This is a way to test your code
assert result == 50, f"Your result is '{result}', but it should be 50"
